# %% [markdown]
# # Lab 1 - My solutions
# **Basics of numpy and matplotlib**<br>
# Software 1 - Mathematics<br>
# Information and Communication Technology<br>
# Metropolia University of Applied Sciences

# %% [markdown]
# ## Setup

# %%
name = "Salahaddin Maroufyan" # Write your name between the parenthesis
student_id = 12345678 # Change your student ID here
date_returned = "31.03.2026" # Write the date returned between the parenthesis

# %%
from IPython.display import Markdown, display # IPython.display is used to display Markdown text in Jupyter notebooks
import numpy as np # numpy is used for numerical calculations
import matplotlib.pyplot as plt # matplotlib is used for plotting graphics
import labx as mx # Remember to download labx module from OMA assignment !!!
# Out:
# C:\Users\Silence\PycharmProjects\JupyterProject\labx.py:76: SyntaxWarning: invalid escape sequence '\i'
#   return txt
# C:\Users\Silence\PycharmProjects\JupyterProject\labx.py:74: SyntaxWarning: invalid escape sequence '\l'
#   lines to the plots to make them easier to read."""
# C:\Users\Silence\PycharmProjects\JupyterProject\labx.py:74: SyntaxWarning: invalid escape sequence '\l'
#   lines to the plots to make them easier to read."""
# C:\Users\Silence\PycharmProjects\JupyterProject\labx.py:106: SyntaxWarning: invalid escape sequence '\i'
#   return txt

# %% [markdown]
# ---
# ## My solution for problem 1

# %%
x = np.arange(-10, 10, 0.001)
y = mx.lab_1_problem_1(x, student_id)

plt.figure(figsize=(8,5))
plt.plot(x, y)

plt.title(f"Function f(x) for student {student_id}")
plt.xlabel("x")
plt.ylabel("f(x)")

plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## My solution for problem 2

# %%
plt.figure(figsize=(7,5))
plt.plot(x, y)
plt.xlim(-1, 1.5)
plt.ylim(0, 2)
plt.axhline(y=1, color='r', linestyle='--')
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Point 1 - Zoomed view")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.plot(x, y)
plt.xlim(5, 7)
plt.ylim(0, 2)
plt.axhline(y=1, color='r', linestyle='--')
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Point 2 - Zoomed view")
plt.grid(True)
plt.show()

# %% [markdown]
# Intersection points:
#
# x1 ≈ 0.05
# x2 ≈ 6.75
