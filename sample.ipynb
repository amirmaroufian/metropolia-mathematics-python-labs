# %%
import numpy as np

# Convert a list to an array
x = np.array([1, 2, 3, 4])

# Create a range of numbers
x2 = np.arange(1, 5, 0.1) # Note: 5 (end) is excluded.

# Create equally spaced array
x3 = np.linspace(1, 5, 20) # Note: 5 (end) is included.

# %%
# %%sql
